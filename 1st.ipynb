# %% [markdown]
# <a href="https://colab.research.google.com/github/devrajbudhathoki222-hub/python-class/blob/main/1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("my name is dev")#this is name
# Out:
# my name is dev

# %%
print("im from nepal")#country name
# Out:
# im from nepal

# %%
print("i am learning python")#python langauge
# Out:
# i am learning python

# %%
name="dev raj budhathoki"
age=25
country="nepal"

# %%
print(name)
# Out:
# dev raj budhathoki

# %%
print(age)
# Out:
# 25

# %%
print(country)
# Out:
# nepal

# %%
print("my name is",name)
print("my age is",age)
# Out:
# my name is dev raj budhathoki
# my age is 25

# %%
height=24.5
isstudent=True

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
print(type(height))
# Out:
# <class 'float'>

# %%
print(type(isstudent))
# Out:
# <class 'bool'>

# %%
5+10
# Out:
# 15

# %%
4-2
# Out:
# 2

# %%
a=10
b=3

# %%
add=a+b
print(add)
# Out:
# 13

# %%
print("addition is ",a+b)
# Out:
# addition is  13

# %%
print("a power b is:",a**b)
# Out:
# a power b is: 1000

# %%
print("reminder is:",a%b)
# Out:
# reminder is: 1

# %%
fname="dev raj"
lname="budhathoki"

# %%
fullname=fname+""+lname
print(fullname)
# Out:
# dev rajbudhathoki

# %%
text="machine learning"
print(text.upper())
# Out:
# MACHINE LEARNING

# %%
print(text.lower())
# Out:
# machine learning

# %%
print(len(text))
# Out:
# 16

# %%
name=input("enter your name:")
print("hello,namaste",name)
# Out:
# enter your name:dev raj
# hello,namaste dev raj

# %%
age=int(input("enter your age"))
print("your age is",age)
# Out:
# enter your age16
# your age is 16

# %%
print("nexr year you will be:",age+1)
# Out:
# nexr year you will be: 17

# %%
marks=[60,75,80,90,55]

# %%
print(marks)
# Out:
# [60, 75, 80, 90, 55]

# %%
print(marks[0])
# Out:
# 60

# %%
print(marks[4])
# Out:
# 55

# %%
secondyear=["dev","ram","shyam","ram","sita"]

# %%
print(secondyear[4])
# Out:
# sita

# %%
secondyear.append("gita")

# %%
print(secondyear)
# Out:
# ['dev', 'ram', 'shyam', 'ram', 'sita', 'gita']

# %%
print(len(secondyear))
# Out:
# 6

# %%
marks=[60,75,80,90,55]

# %%
print("max",max(marks))
# Out:
# max 90

# %%
print("min",min(marks))
# Out:
# min 55

# %%
print("sum",sum(marks))
# Out:
# sum 360

# %%
marks=70
if marks>=60:
  print("pass")
else:
  print("fail")
# Out:
# pass

# %%
age=18
if age>=20:
  print("can vote")
else:
  print("you can`t vote")
# Out:
# you can`t vote

# %%
marks=89

if marks>=90:
  print("Arade A")
elif marks>-80:
  print("Grade B")
elif marks>-70:
  print("Grade C")
elif marks>-60:
  print("Grade D")
else:
  print("Fail")
# Out:
# Grade B
